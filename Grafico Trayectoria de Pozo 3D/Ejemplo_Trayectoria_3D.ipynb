# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Pozo.csv')
data.head()
# Out:
#      MD            X            Y          Z        TVD            DX  \
# 0   0.0  589178.7500  2155844.750  36.700000   0.000000  1.500000e-09
# 1  15.0  589178.7508  2155844.753  21.700000  15.000000  7.509430e-04
# 2  30.0  589178.7530  2155844.763   6.700004  29.999996  3.003767e-03
# 3  45.0  589178.7484  2155844.768  -8.299993  44.999993 -1.578452e-03
# 4  60.0  589178.7287  2155844.760 -23.299977  59.999977 -2.133264e-02
#
#              DY     AZIM_TN      INCL       DLS     AZIM_GN
# 0  1.900000e-09    0.283630  0.000000  0.000000    0.000000
# 1  3.184155e-03   13.553630  0.025000  0.050000   13.270000
# 2  1.273661e-02   13.553630  0.050000  0.050000   13.270000
# 3  1.842514e-02  263.908402  0.046782  0.158258  263.624772
# 4  1.001750e-02  240.803630  0.120000  0.158258  240.520000

# %%
import plotly.express as px

data['TVD'] = -data['TVD']

fig = px.line_3d(data, x="DX", y="DY", z="TVD")

fig.show()
